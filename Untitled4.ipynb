# %% [markdown]
# <a href="https://colab.research.google.com/github/Thewaiii/BSC_DPDM23/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score

# !pip install apyori
from apyori import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_65=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/accidentmonth.xlsx")
data_64=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2564-t-kh-63-k-y-64.xlsx")
data_63=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2563-t-kh-62-k-y-63.xlsx")
data_62=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2562-t-kh-61-k-y-62.xlsx")
data_61=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2561-t-kh-60-k-y-61.xlsx")
data_60=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2560-t-kh-59-k-y-60.xlsx")
data_59=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/project/kh-muul-ubatiehtubnthaangphiess-piingbpramaan-2559-t-kh-58-k-y-59.xlsx")
data_more=pd.read_excel('/content/drive/MyDrive/BSC_DBDM23/project/moredata.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f'ปี 2565 \n{data_65.isnull().any()}')
print(f'ปี 2564 \n{data_64.isnull().any()}')
print(f'ปี 2563 \n{data_63.isnull().any()}')
print(f'ปี 2562 \n{data_62.isnull().any()}')
print(f'ปี 2561 \n{data_61.isnull().any()}')
print(f'ปี 2560 \n{data_60.isnull().any()}')
print(f'ปี 2559 \n{data_59.isnull().any()}')
# Out:
# ปี 2565
# accident_date    False
# accident_time    False
# expw_step        False
# weather_state    False
# injur_man        False
# injur_femel      False
# dead_man         False
# dead_femel       False
# cause            False
# dtype: bool
# ปี 2564
# accident_date    False
# accident_time    False
# step             False
# ad_state         False
# acman_rec        False
# acfem_rec        False
# deadman_rec      False
# deadfem_rec      False
# cause_type       False
# dtype: bool
# ปี 2563
# accident_date    False
# accident_time    False
# expw_step        False
# weather_state    False
# injur_man        False
# injur_femel      False
# dead_man         False
# dead_femel       False
# cause            False
# dtype: bool
# ปี 2562
# accident_date    False
# accident_time    False
# expw_step        False
# weather_state    False
# injur_man        False
# injur_femel      False
# dead_man         False
# dead_femel       False
# cause            False
# dtype: bool
# ...

# %% [markdown]
# Concat Dataframe each year (All years: 2559-2565)

# %%
pd.concat([data_59,data_60,data_61,data_62,data_63,data_64,data_65]).head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   accident_date accident_time expw_step weather_state  injur_man  injur_femel  \
# 0    2016-03-15      07:23:23    ศรีรัช          ปกติ        0.0          0.0
# 1    2016-07-27      12:22:22    ศรีรัช          ปกติ        0.0          0.0
# 2    2015-12-09      14:40:40    ศรีรัช          ปกติ        0.0          0.0
# 3    2016-08-20      17:01:01    ศรีรัช          ปกติ        0.0          0.0
# 4    2016-04-23      09:18:18    ศรีรัช          ปกติ        0.0          0.0
#
#    dead_man  dead_femel                      cause step ad_state  acman_rec  \
# ...

# %%
print(f'column ปี 65 \n{data_65.columns}')
print(f'column ปี 64 \n{data_64.columns}')
print(f'column ปี 63 \n{data_63.columns}')
print(f'column ปี 62 \n{data_62.columns}')
print(f'column ปี 61 \n{data_61.columns}')
print(f'column ปี 60 \n{data_60.columns}')
print(f'column ปี 59 \n{data_59.columns}')
# Out:
# column ปี 65
# Index(['accident_date', 'accident_time', 'expw_step', 'weather_state',
#        'injur_man', 'injur_femel', 'dead_man', 'dead_femel', 'cause'],
#       dtype='object')
# column ปี 64
# Index(['accident_date', 'accident_time', 'step', 'ad_state', 'acman_rec',
#        'acfem_rec', 'deadman_rec', 'deadfem_rec', 'cause_type'],
#       dtype='object')
# column ปี 63
# Index(['accident_date', 'accident_time', 'expw_step', 'weather_state',
#        'injur_man', 'injur_femel', 'dead_man', 'dead_femel', 'cause'],
#       dtype='object')
# column ปี 62
# Index(['accident_date', 'accident_time', 'expw_step', 'weather_state',
#        'injur_man', 'injur_femel', 'dead_man', 'dead_femel', 'cause'],
#       dtype='object')
# column ปี 61
# Index(['accident_date', 'accident_time', 'expw_step', 'weather_state',
#        'injur_man', 'injur_femel', 'dead_man', 'dead_femel', 'cause'],
#       dtype='object')
# column ปี 60
# ...

# %%
data_64=data_64.rename(columns = {'step':'expw_step','ad_state':'weather_state','acman_rec':'injur_man','acfem_rec':'injur_femel'
,'deadman_rec':'dead_man','deadfem_rec':'dead_femel','cause_type':'cause'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
use_data=pd.concat([data_59,data_60,data_61,data_62,data_63,data_64,data_65]).reset_index().drop("index",axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
type(use_data['accident_time'][0])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# datetime.time

# %% [markdown]
# จัดกลุ่มแต่ละเวลาให้แบ่งเป็นช่วงเวลา

# %%
import datetime
def time_in_range(start, end, x):
    """Return true if x is in the range [start, end]"""
    if start <= end:
        return start <= x <= end
    else:
        return start <= x or x <= end
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
time_lable=[]
how =[]
#เช้า
start_0 = datetime.time(6, 0, 0)
end_0 = datetime.time(11, 59, 59)
#บ่าย
start_1 = datetime.time(12, 0, 0)
end_1 = datetime.time(17, 59, 59)
#ดึก
start_2 = datetime.time(18, 0, 0)
end_2 = datetime.time(23, 59, 59)
#หลังเที่ยงคืน
start_3 = datetime.time(0, 0, 0)
end_3 = datetime.time(5, 59, 59)
for i in range(len(use_data['accident_time'])):
  if time_in_range(start_0, end_0, use_data['accident_time'][i]) == True:
    time_lable.append(0)
  elif time_in_range(start_1, end_1, use_data['accident_time'][i]) == True:
    time_lable.append(1)
  elif time_in_range(start_2, end_2, use_data['accident_time'][i]) == True:
    time_lable.append(2)
  elif time_in_range(start_3, end_3, use_data['accident_time'][i]) == True:
    time_lable.append(3)
  else:
    how.append(i)
how
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# []

# %%
use_data['time_lable']=time_lable
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
use_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   accident_date accident_time expw_step weather_state  injur_man  injur_femel  \
# 0    2016-03-15      07:23:23    ศรีรัช          ปกติ          0            0
# 1    2016-07-27      12:22:22    ศรีรัช          ปกติ          0            0
# 2    2015-12-09      14:40:40    ศรีรัช          ปกติ          0            0
# 3    2016-08-20      17:01:01    ศรีรัช          ปกติ          0            0
# 4    2016-04-23      09:18:18    ศรีรัช          ปกติ          0            0
#
#    dead_man  dead_femel                      cause  time_lable
# 0         0           0                โรคประจำตัว           0
# ...

# %% [markdown]
# แยก วัน/เดือน/ปี ออกจากกัน

# %% [markdown]
# เเปลง time stamp ที่เป็นฟังก์ชัน strptime() ให้เป็น string

# %%
cov_time_sti =use_data['accident_date'].apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
cov_time_sti[0].split()[0].split('-')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['2016', '03', '15']

# %%
day=[]
mon=[]
year=[]
for i in range(len(cov_time_sti)):
  L=cov_time_sti[i].split()[0].split('-')
  year.append(L[0])
  mon.append(L[1])
  day.append(L[2])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f'count_row_day = {len(day)}')
print(f'count_row_mon = {len(mon)}')
print(f'count_row_yeat = {len(year)}')
# Out:
# count_row_day = 6557
# count_row_mon = 6557
# count_row_yeat = 6557
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# กำหนดตัวเลข แทน ชื่อถนน

# %%
set(use_data['expw_step'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'S1',
#  'ฉลองรัช',
#  'ทางหลวงพิเศษหมายเลข 37',
#  'บางพลี-สุขสวัสดิ์',
#  'บูรพาวิถี',
#  'ศรีรัช',
#  'ศรีรัช-วงแหวนรอบนอก',
#  'อุดรรัถยา',
#  'เฉลิมมหานคร'}

# %%
use_data.to_excel('use_data.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# กำหนดตัวเลข แทน สภาพอากาศ

# %%
set(use_data['weather_state'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'กลางคืน',
#  'ถนนเปียก',
#  'ถนนเปียกรื่น',
#  'ถนนเปียกลื่น',
#  'ท้องฟ้ามืดครึ้ม',
#  'ปกติ',
#  'ฝนตก',
#  'ฝนตกลมแรง'}

# %%
weather_road=[]
for i in range(len(use_data['weather_state'])):
  if use_data['weather_state'][i] == 'ปกติ':
    weather_road.append('0')
  elif (use_data['weather_state'][i] == 'ฝนตก') | (use_data['weather_state'][i] == 'ท้องฟ้ามืดครึ้ม') |(use_data['weather_state'][i] == 'ฝนตกลมแรง'):
    weather_road.append('1')
  elif use_data['weather_state'][i] == 'กลางคืน':
    weather_road.append('2')
  elif (use_data['weather_state'][i] == 'ถนนเปียกรื่น') |(use_data['weather_state'][i] == 'ถนนเปียกลื่น')|(use_data['weather_state'][i] == 'ถนนเปียก') :
    weather_road.append('3')
  else:
    print(i)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
injur =[]
for i in range(len(use_data['injur_man'])):
  if (use_data['injur_man'][i] == 0 ) and (use_data['injur_femel'][i] == 0):
    injur.append('0')
  elif (use_data['injur_man'][i] > 0) and (use_data['injur_femel'][i] == 0):
    injur.append('1')
  elif (use_data['injur_man'][i] == 0) and (use_data['injur_femel'][i] > 0):
    injur.append('2')
  elif (use_data['injur_man'][i] > 0) and (use_data['injur_femel'][i] > 0):
    injur.append('3')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dead =[]
for i in range(len(use_data['dead_man'])):
  if (use_data['dead_man'][i] == 0 ) and (use_data['dead_femel'][i] == 0):
    dead.append('0')
  elif (use_data['dead_man'][i] > 0) or (use_data['dead_femel'][i] > 0):
    dead.append('1')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
name_road=[]
for i in range(len(use_data['expw_step'])):
  if use_data['expw_step'][i] == 'ศรีรัช':
    name_road.append('0')
  elif use_data['expw_step'][i] == 'ฉลองรัช':
    name_road.append('1')
  elif use_data['expw_step'][i] == 'บูรพาวิถี':
    name_road.append('2')
  elif use_data['expw_step'][i] == 'อุดรรัถยา':
    name_road.append('3')
  elif use_data['expw_step'][i] == 'เฉลิมมหานคร':
    name_road.append('4')
  elif use_data['expw_step'][i] == 'บางพลี-สุขสวัสดิ์':
    name_road.append('5')
  elif use_data['expw_step'][i] == 'ทางหลวงพิเศษหมายเลข 37':
    name_road.append('6')
  elif use_data['expw_step'][i] == 'ศรีรัช-วงแหวนรอบนอก':
    name_road.append('7')
  elif use_data['expw_step'][i] == 'S1':
    name_road.append('8')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Group Data

# %%
new1 = data_more[['cause_A','cause_D']].replace(0,np.nan)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
newk = []
for i in range(len(new1['cause_D'])):
  if (new1['cause_D'][i] == 'เกิดจากตนเอง' ) :
    newk.append('0')
  elif (new1['cause_D'][i] == 'เกิดจากคนอื่น' ) :
    newk.append('1')
  elif (new1['cause_D'][i] == 'เกิดจากสภาพเเวดล้อมเเละรถ' ) :
    newk.append('2')
  else:
    newk.append(np.nan)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_association_rules = []
for i in range(len(data_more['cause_A'])):
  x = new1['cause_A'][i]
  data_association_rules.append(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##จัดกลุ่ม

# %%
newgroup = use_data['cause'].str.strip()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
set(newgroup )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'-',
#  '.',
#  'กระจกแตก',
#  'กระชั้นชิดเบรกไม่ทัน',
#  'กระบะToyotaทำสิ่งของตกหล่น',
#  'กระบะจอดช่วงทางโค้ง',
#  'กระบะจอดตรวจสอบสิ่งของ',
#  'กระบะจอดเสียเลนกลาง',
#  'กระบะบรรทุกสูง',
#  'กระบะเบรคกะทันหัน',
#  'กระระยะผิดก่อนเจ้าตู้2',
#  'กลับรถไม่พ้น',
#  'กะระยะเข้าช่องทางไม่ถูก',
#  'กำลังจะไปช่วย ว.40 ขึ้นบรมฯ',
#  'ก้มดูโทรศัพย์',
#  'ก้มรับโทรศัพท์',
#  'ก้มหยิบของ',
#  'ก้มหยิบเงิน',
#  'ก้มหยิบโทรศัพท์',
#  'ก้มหยิบโทรศัพย์',
#  'ก้มหาเงินค่าผ่านทาง',
#  'ก้มเก็บของ',
#  'ก้มเก็บของในรถ',
#  'ก้มเก็บสิ่งของ',
#  'ก้มเก็บสิ่งของในห้องโดยสาร',
#  'ก้มเก็บเงิน',
#  'ก้มเก็บโทรศัพท์',
#  'ก้มเก็บโทรศัพย์',
# ...

# %%
 v0={'ก้มหยิบของ':'ก้มเก็บของ' ,'ก้มหยิบเงิน':'ก้มเก็บของ','ก้มหยิบโทรศัพท์':'ก้มเก็บของ' ,'ก้มหยิบโทรศัพย์':'ก้มเก็บของ'
  ,'ก้มหาเงินค่าผ่านทาง':'ก้มเก็บของ' ,'ก้มเก็บของ':'ก้มเก็บของ' ,'ก้มเก็บของในรถ':'ก้มเก็บของ' ,'ก้มเก็บสิ่งของ':'ก้มเก็บของ'
   ,'ก้มเก็บสิ่งของในห้องโดยสาร':'ก้มเก็บของ' , 'ก้มเก็บเงิน':'ก้มเก็บของ' ,'ก้มเก็บโทรศัพท์':'ก้มเก็บของ' ,'ก้มเก็บโทรศัพย์':'ก้มเก็บของ'
     ,'ก้มดูโทรศัพย์':'ก้มเก็บของ' ,'ก้มรับโทรศัพท์':'ก้มเก็บของ' ,'ทำโทรศัพย์หล่นแล้วก้มหยิบ':'ก้มเก็บของ' ,'นั่งบุลคลอีซูซุก้มเก็บของ':'ก้มเก็บของ'
  ,'ประมาท ก้มหยิบของ':'ก้มเก็บของ' ,'ผู้ขับขี่ก้มหยิบของ':'ก้มเก็บของ' ,'หยิบของในรถ':'ก้มเก็บของ', }
newgroup.replace(v0)

v1={ 'กำลังจะไปช่วย ว.40 ขึ้นบรมฯ':'การทำงานของราชการ','ตร.เรียกรถจอดออกหนังสือคำสั่ง':'การทำงานของราชการ','ลากกันมา':'การทำงานของราชการ'}
newgroup.replace(v1)

v2={ 'กระบะToyotaทำสิ่งของตกหล่น':'ของตกจากรถ','มีกรงสุนัขตกหล่น':'ของตกจากรถ','มีเก้าอี้ตกหล่น':'ของตกจากรถ','ลงมาเก็บสิ่งของตกหล่นเลนขวา':'ของตกจากรถ'}
newgroup.replace(v2)

v3={ 'ขับขี่ย้อนศร':'ขับขี่ย้อนศร','ขับขี่ย้อนเส้นทาง':'ขับขี่ย้อนศร','ขับย้อนทิศทางเดินรถ':'ขับขี่ย้อนศร','ขับขี่ย้อนศร':'ขับย้อนศร',
    'ขับย้อนศรแล้วชน':'ขับย้อนศร','ขับย้อนเส้นทาง':'ขับย้อนศร','ขับรถย้อนทาง':'ขับย้อนศร','ขับรถย้อนทางมาจากทางลงสุขุมวิท':'ขับย้อนศร',
     'ขับสวนเลน':'ขับย้อนศร','จยย.ย้อนศร':'ขับย้อนศร','มึนเมาแล้วขี่ย้อนศรทางเข้าด่าน':'ขับย้อนศร','ย้อนทางเข้าด่าน':'ขับย้อนศร'
   ,'ย้อนทางลงขึ้นมา':'ขับขี่ย้อนศร','ย้อนออกด่าน':'ขับขี่ย้อนศร','รถนั่งฮอนด้าขับย้อนทางลงพัฒ2':'ขับขี่ย้อนศร','วิ่งย้อนทางลงสุขุมวิท50ขึ้นมา':'ขับย้อนศร',}
newgroup.replace(v3)

v4={ 'กลับรถไม่พ้น':'ขับชิดขอบทาง' , 'ขับชิดขวามากเกินไป': 'ขับชิดขอบทาง' , 'ขับชิดขวามากเกินไป':'ขับชิดขอบทาง',
    'ขับชิดขอบเกินไป': 'ขับชิดขอบทาง','ขับชิดขอบตู้มากเกิน': 'ขับชิดขอบทาง','ขับชิดขอบทางขวามากเกินไป': 'ขับชิดขอบทาง',
   'ขับชิดขอบทางซ้าย': 'ขับชิดขอบทาง','ขับชิดขอบทางมาก': 'ขับชิดขอบทาง','ขับชิดซ้ายมากเกินไป': 'ขับชิดขอบทาง',
     'ขับชิดมากเกินไป': 'ขับชิดขอบทาง' ,'ขับรถมุดเลนซ้าย':'ขับชิดขอบทาง',}

v5={  'ขับรถในระยะกระชันชิด':'ขับรถกระชั้นชิด' ,' ขับรถในระยะกระชั้นชิด':'ขับรถกระชั้นชิด',
    '  ขับรถระยะกระชั้นชิด':'ขับรถกระชั้นชิด' , 'เดินรถบนไหล่ทางซ้าย':'ขับรถกระชั้นชิด' , 'เดินรถไหล่ทางซ้าย':'ขับรถกระชั้นชิด'
      ,'โดนรถบรรทุกเบียด':'ขับรถกระชั้นชิด' ,  'ถูกรถร่วมทางเบียด':'ขับรถกระชั้นชิด' ,  'เบรกกระชั้นชิด':'ขับรถกระชั้นชิด' ,
      'เปลี่ยนช่องทางกะทันหัน':'ขับรถกระชั้นชิด' , 'รถบรรทุกตัดหน้า':'ขับรถกระชั้นชิด',}
newgroup.replace(v5)

v6={ 'กระบะจอดช่วงทางโค้ง':'ขับรถประมาท' , 'กระบะจอดตรวจสอบสิ่งของ':'ขับรถประมาท' , 'ขับปาดกันไปมา':'ขับรถประมาท'
 , 'ขับรถคล่อมเลน':'ขับรถประมาท' , 'ขับรถชนป้าย':'ขับรถประมาท' , 'ช่องทางEasypass':'ขับรถประมาท',
  'ขับรถด้วยความประมาท':'ขับรถประมาท' , 'ขับรถโดยประมาท':'ขับรถประมาท' , 'ขับรถประมาท':'ขับรถประมาท' ,
 'ขับรถปาดกันไป มา':'ขับรถประมาท' ,' ขับรถมองข้างทาง':'ขับรถประมาท' , 'ขับรถไม่ชำนาญ':'ขับรถประมาท' ,
'ขับรถเร็วในช่องทางฉุกเฉิน':'ขับรถประมาท', 'ขับรถออกมองไม่เห็น':'ขับรถประมาท' , 'ขับเร็วเสียหลัก':'ขับรถประมาท' ,
 'ควบคุมรถไม่ได้':'ขับรถประมาท' , 'ชะลอดูว.40ฝั่งตรงข้าม':'ขับรถประมาท' , 'ใช้ความเร็วเข้าโค้ง':'ขับรถประมาท' ,
 'ใช้ความเร็วในการเข้าโค้ง':'ขับรถประมาท' , 'ใช้โทรศัพท์ขณะขับรถ':'ขับรถประมาท' , 'นับเงินทอนค่าผ่านทาง':'ขับรถประมาท' ,
'ประมาณ':'ขับรถประมาท' , 'ประมาท':'ขับรถประมาท' , 'ประมาท ขับรถเร็ว':'ขับรถประมาท' ,
' ประมาทขาดความระวัง':'ขับรถประมาท' , 'เปิดประตูชำระค่าผ่านทาง':'ขับรถประมาท' , 'เปิดประตูมารับบัตรแล้วกระแทกตู':'ขับรถประมาท'
, 'เปิดประตูรถ':'ขับรถประมาท',  'ผู้ขับขี่ขับรถประมาณ':'ขับรถประมาท' , 'ผู้ขับขี่นั่งบุคคลก้มดูโทรศัพท':'ขับรถประมาท'
, 'มีสิ่งของขัดเบรกทำให้เกิดว40':'ขับรถประมาท' , 'ไม่ชะลอความเร็ว':'ขับรถประมาท' , 'ไม่ชินเส้นทาง':'ขับรถประมาท'
, 'ไม่ดึงเบรกมือ':'ขับรถประมาท' , 'ไม่ดึงเบรกมือทำให้รถไหลตกท่อ':'ขับรถประมาท' , 'ไม่ได้ปิดประตูตู้บรรทุก':'ขับรถประมาท' ,'ไม่ได้ล็อคตู้':'ขับรถประมาท'
, 'ไม่ทันมอง':'ขับรถประมาท' , 'ไม่ทันสังเกต':'ขับรถประมาท' , 'ไม่ระมัดระวัง':'ขับรถประมาท' , 'รถจอดเลนกลางโดนชนท้าย':'ขับรถประมาท'
 , 'รถบรรทุก6ล้อ เข้าผิดเวลา':'ขับรถประมาท' , 'รองเท้าเบ้าไปขัดขาเบรค':'ขับรถประมาท' , 'ละสายตา':'ขับรถประมาท' , 'ละสายตาจากการขับขี่':'ขับรถประมาท'
     , 'เล่นโทรศัพท์':'ขับรถประมาท' , 'หยุดรถไม่ทัน':'ขับรถประมาท' , 'เหม่อลอย':'ขับรถประมาท',}
newgroup.replace(v6)

v7={'ขับรถเร็ว':'ขับรถเร็วเกินไป', 'ข้ับรถเร็ว':'ขับรถเร็วเกินไป',  'ขับรถเร็ว':'ขับรถเร็วเกินไป', 'ประมาท':'ขับรถเร็วเกินไป',
    'ขับรถเร็วเกินไป':'ขับรถเร็วเกินไป', 'ขับเร็วเฉี่ยวชนท้าย':'ขับรถเร็วเกินไป',}
newgroup.replace(v7)

v8={'ขับรถช้าลง':'ขับรถช้าเกินไป'}
 newgroup.replace(v8)

v9={'กระบะบรรทุกสูง':'บรรทุกเกิน','ชนป้ายวัดความสูง':'บรรทุกเกิน','บรรทุกกว้างยื่นล้ำ':'บรรทุกเกิน','บรรทุกเกิน/ของตกหล่น':'บรรทุกเกิน','บรรทุกเกินตัวรถ':'บรรทุกเกิน','บรรทุกมาสูง':'บรรทุกเกิน','บรรทุกยื่นล้ำ':'บรรทุกเกิน',
   'บรรทุกยื่นล้ำตัวรถ':'บรรทุกเกิน','บรรทุกสิ่งของกว้างเกินไป':'บรรทุกเกิน','บรรทุกสิ่งของยื้นล้ำ':'บรรทุกเกิน','บรรทุกสูง':'บรรทุกเกิน','บรรทุกสูงเกิน':'บรรทุกเกิน','บรรทุกสูงหนัก':'บรรทุกเกิน','บรรทุกสูงหนักเกินไป':'บรรทุกเกิน',
   'เบรคไม่อยู่รถบรรทุกหนัก':'บรรทุกเกิน','รถบรรทุกหนัก':'บรรทุกเกิน'}
 newgroup.replace(v9)

v10={'กระบะเบรคกะทันหัน':'เบรครถกระทันหัน','นั่งบุคคลMazdaเบรกกะทันหัน':'เบรครถกระทันหัน','เบครกระทันหัน':'เบรครถกระทันหัน','เบรกกระชั้นชิด':'เบรครถกระทันหัน','เบรกกระทันหัน':'เบรครถกระทันหัน','เบรกกะทันหัน':'เบรครถกระทันหัน',
   'เบรกกะทันหันรถเสียการทรงตัว':'เบรครถกระทันหัน','เบรกไม่อยู่':'เบรครถกระทันหัน','เบรกแล้วเสียหลักพลิกคว่ำ':'เบรครถกระทันหัน','เบรคกระทันหหัน':'เบรครถกระทันหัน','เบรคกระทันหัน':'เบรครถกระทันหัน','เบรคกระทันหันเ':'เบรครถกระทันหัน',
   'เบรคกะทันหัน':'เบรครถกระทันหัน','เบรคไม่ทัน':'เบรครถกระทันหัน','เบรคไม่อยู่':'เบรครถกระทันหัน','เบรครถกระทันหัน':'เบรครถกระทันหัน','เบรครถกระทันหันแล้วพลิ๊กคว่ำ':'เบรครถกระทันหัน','เบรคแล้วเสียหลัก':'เบรครถกระทันหัน',
   'เบลคกระทันหัน':'เบรครถกระทันหัน','เปลี่ยนช่องทางเบรกกะทันหัน':'เบรครถกระทันหัน','ผู้ขับขี่เบรคกระทันหัน':'เบรครถกระทันหัน','ผู้ขับขี่เบรคไม่ทัน':'เบรครถกระทันหัน','เลรคกะทันหัน':'เบรครถกระทันหัน','เหยียบเบรคกระทันหัน':'เบรครถกระทันหัน',
   'เปลี่ยนช่องทางกระทันหัน':'เปลี่ยนช่องทางกระทันหัน'}
 newgroup.replace(v10)

v11={'ฝ่าฝืนสัญญาณ/ป้ายจราจร':'ฝ่าฝืนกฎจราจร'}
 newgroup.replace(v11)

v12={ 'คล้ายมีอาการมึนเมา':'มึนเมา','มึนเมา':'มึนเมา','เมาจอดนอนกีดขวาง':'มึนเมา'}
 newgroup.replace(v12)

v13={ 'เสียหลัก':'เสียหลัก', 'เสียหลักจากช่ิองทางด้านขวา':'เสียหลัก', 'เสียหลักพลิกคว่ำ':'เสียหลัก', 'เสียหลักหมุนชนขอบทาง':'เสียหลัก',}
 newgroup.replace(v13)

v14={ 'ป่วย':'โรคประจำตัว', 'ผู้ขับขี่หมดสติ':'โรคประจำตัว', 'โรคประจำตัว':'โรคประจำตัว'}
 newgroup.replace(v14)

v15={  'กระจกแตก':'สาเหตุจากสภาพรถ/ถนน', 'กระบะจอดเสียเลนกลาง':'สาเหตุจากสภาพรถ/ถนน', 'แก๊สกระป๋องเล็กรั่ว':'สาเหตุจากสภาพรถ/ถนน', 'ขึ้นเนินมองไม่เห็น':'สาเหตุจากสภาพรถ/ถนน', 'ความร้อนขึ้นแล้วฟืนขับต่อ':'สาเหตุจากสภาพรถ/ถนน',
   'เครนฟาดเสาไฟเสียหาย':'สาเหตุจากสภาพรถ/ถนน', 'เครื่องยนต์ขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ช่วงล่างชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'ตัวรถสูง':'สาเหตุจากสภาพรถ/ถนน', 'ถนนเปียกลื่น':'สาเหตุจากสภาพรถ/ถนน',
   'น๊อตล้อหลังขวาขาด':'สาเหตุจากสภาพรถ/ถนน', 'บรรทุกรถ Atvเกิดไฟฟ้าลัดวงจร':'สาเหตุจากสภาพรถ/ถนน', 'เบรกชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'เบรกติด':'สาเหตุจากสภาพรถ/ถนน', 'เบรกติดล้อ':'สาเหตุจากสภาพรถ/ถนน',
   'เบรคขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'เบรคติด':'สาเหตุจากสภาพรถ/ถนน', 'เบรคแตก':'สาเหตุจากสภาพรถ/ถนน', 'ปีกนกซ้ายชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'ฝนตกถนนเปียกลื่น':'สาเหตุจากสภาพรถ/ถนน',
   'ฝนตกถนนลื่น':'สาเหตุจากสภาพรถ/ถนน', 'ฝาท้ายตู้เปิด':'สาเหตุจากสภาพรถ/ถนน', 'พวงมาลัยล็อค':'สาเหตุจากสภาพรถ/ถนน', 'พวงมาลัยล๊อค':'สาเหตุจากสภาพรถ/ถนน', 'พ่วงหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'เพลาข้างด้านขวาขาด':'สาเหตุจากสภาพรถ/ถนน', 'เพลิงไหม้':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้ารัดวงจรในห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้าลัดวงจร':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้าลัดวงจรบริเวณห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน',
   'มองไม่เห็น':'สาเหตุจากสภาพรถ/ถนน', 'มีกลุ่มควันขึ้นมากหลังรถ':'สาเหตุจากสภาพรถ/ถนน', 'มีควันขึ้นที่ห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน', 'มีรถจอดเสียช่องกลาง ชนท้าย':'สาเหตุจากสภาพรถ/ถนน', 'ยากแตก':'สาเหตุจากสภาพรถ/ถนน',
   'ยางแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกล้อหลัง':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกเสียหลัก':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกเสียหลักชนขอบทาง':'สาเหตุจากสภาพรถ/ถนน', 'ยางระเบิด':'สาเหตุจากสภาพรถ/ถนน',
   'ยางล้อหลังขวาระเบิด':'สาเหตุจากสภาพรถ/ถนน', 'ยางหน้าขวาแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลงขวาระเบิด':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลังขวาแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลังซ้ายแตก':'สาเหตุจากสภาพรถ/ถนน',
   'ยางหลังแตก2ข้าง':'สาเหตุจากสภาพรถ/ถนน', 'ยางเเตก':'สาเหตุจากสภาพรถ/ถนน', 'รถเบรกไม่อยู่':'สาเหตุจากสภาพรถ/ถนน', 'รถมีขนาดใหญ่เกินไป':'สาเหตุจากสภาพรถ/ถนน', 'รถยนต์ขัดข้อง':'สาเหตุจากสภาพรถ/ถนน',
   'รถไหล':'สาเหตุจากสภาพรถ/ถนน', 'ระบบไฟฟ้าขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ระบบไฮโดรลิคขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ล้อล็อค':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลังขวาหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'ล้อหลุด':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลุดไปชนรถคู่กรณี':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลุดเสียหลักพลิกคว่ำ':'สาเหตุจากสภาพรถ/ถนน', 'สภาพแวดล้อม':'สาเหตุจากสภาพรถ/ถนน', 'สลักตัวยึดหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'สาเหตุจากสภาพรถ/ถนน':'สาเหตุจากสภาพรถ/ถนน', 'หางพ่วงเรือเจ๊ตสกรีหลุด':'สาเหตุจากสภาพรถ/ถนน', 'เหยียบสิ้งของตกหล่นแผ่นเหล็ก':'สาเหตุจากสภาพรถ/ถนน', 'อุปกรณ์ล้อยางชำรุด':'สาเหตุจากสภาพรถ/ถนน'}
 newgroup.replace(v15)

v16={ 'หลบจักรยานยนต์':'หลบรถ', 'หลบมีรถย้อนทาง':'หลบรถ'}
 newgroup.replace(v16)

v17={ 'สันนิษฐาน หลับใน':'หลับใน', 'หลับใน':'หลับใน'}
 newgroup.replace(v17)

v18={ 'ขับถอยหลัง':'ถอยรถ','ขับรถถอยหลัง':'ถอยรถ','ถอยเบียดแท่นปูน':'ถอยรถ','ถอยหลบมองไม่เห็นชนป้ายจราจร':'ถอยรถ','ถอยหลังเข้าตู้ผิด':'ถอยรถ','ถอยหลังจอด':'ถอยรถ','ถอยหลังชน':'ถอยรถ','ถอยหลังชนไม้กั้น':'ถอยรถ','ถอยหลังชิดขอบทางขวามากเกินไป':'ถอยรถ','ถอยหลังชิดด้านซ้ายมากเกินไป':'ถอยรถ','ถอยหลังรถไปชน':'ถอยรถ','ถอยหลังลงจากต่างระดับ':'ถอยรถ','นั่งสาธารณะขับเลยทางลงถอยหลัง':'ถอยรถ',}
 newgroup.replace(v18)

v19={'ชนแล้วหลบหนี':'ชนแล้วหลบหนี'}
 newgroup.replace(v19)

v20={ 'คันที่3หยุดรถไม่ทัน':'ชนท้าย','ชนท้าย':'ชนท้าย','ชนท้ายตามลำดับ':'ชนท้าย','ชนท้ายรถบรรทุก':'ชนท้าย','โดนชนท้าย':'ชนท้าย','นั่งบุคคลIsuzuเบรคไม่ทัน':'ชนท้าย'}
 newgroup.replace(v20)

v21={'เฉี่ยวชนก้างปลา':'เฉี่ยวชน','เฉียวชนแล้วหลบหนี':'เฉี่ยวชน','เชี่ยวชน':'เฉี่ยวชน','โดนตัดหน้า':'เฉี่ยวชน','โดนปาดหน้า':'เฉี่ยวชน','นั่งบุคคลตัดหน้ารถบรรทุก10ล้อ':'เฉี่ยวชน','มีรถปาดหน้า':'เฉี่ยวชน'}
 newgroup.replace(v21)

v22={ 'ขับรถในช่องทางฉุกเฉิน':'เข้าผิดช่อง','เข้าช่องetc':'เข้าผิดช่อง','เข้าช่องเก็บค่าผ่านทางผิด':'เข้าผิดช่อง','เข้าช่องเก็บค่าผ่านผิด':'เข้าผิดช่อง','เข้าช่องเก็บเงินผิด':'เข้าผิดช่อง','เข้าช่องทางผิด':'เข้าผิดช่อง','เข้าช่องทางผิดเเล้วถอยรถออก':'เข้าผิดช่อง','เข้าผิดช่องทาง':'เข้าผิดช่อง','เข้าผิดช่ิอง':'เข้าผิดช่อง','เข้าผิดตู้':'เข้าผิดช่อง','เข้าผิดเลนถอยชนไฟส่องล้อเสียหา':'เข้าผิดช่อง','จอดในช่องเดินรถซ้าย':'เข้าผิดช่อง','จอดเลนฉุกเฉิน':'เข้าผิดช่อง','เดินรถในเลนฉุกเฉิน':'เข้าผิดช่อง','พลัดหลง':'เข้าผิดช่อง','ไม่มีeasy pass':'เข้าผิดช่อง','ไม่มีอีซี่พาส':'เข้าผิดช่อง','รถไม่่มี Easy Pass':'เข้าผิดช่อง','ลงผิดทางถอยหลัง':'เข้าผิดช่อง','วิ่งช่องฉุกเฉิน':'เข้าผิดช่อง','วิ่งเลนฉุกเฉิน':'เข้าผิดช่อง','หลงทาง':'เข้าผิดช่อง','หลงทางแล้วถอยชน':'เข้าผิดช่อง'}
 newgroup.replace(v22)

v23={}
 newgroup.replace(v23)
v24={}
 newgroup.replace(v24)

v25={}
 newgroup.replace(v25)

v26={}
 newgroup.replace(v26)


print(len(set(v0)))
print(len(set(v1)))
print(len(set(v2)))
print(len(set(v3)))
print(len(set(v4)))
print(len(set(v5)))
print(len(set(v6)))
print(len(set(v7)))
print(len(set(v8)))
print(len(set(v9)))
print(len(set(v10)))
print(len(set(v11)))
print(len(set(v12)))
print(len(set(v13)))
print(len(set(v14)))
print(len(set(v15)))
print(len(set(v16)))
print(len(set(v17)))
print(len(set(v18)))
print(len(set(v19)))
print(len(set(v20)))
print(len(set(v21)))
print(len(set(v22)))
print(len(set(v23)))
print(len(set(v24)))
print(len(set(v25)))
print(len(set(v26)))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 19
# 3
# 4
# 15
# 10
# 10
# 49
# 5
# 1
# 16
# 25
# 1
# 3
# 4
# 3
# 64
# 2
# 2
# 13
# 1
# 6
# 7
# 23
# 0
# 0
# 0
# 0

# %%
k={'-':np.nan,'.':np.nan,' ':np.nan,'รอตรวจสอบ':np.nan,'รอตรวจสอบ':np.nan,np.nan:'ไม่ทราบ',np.nan:'ไม่ทราบสาเหตุ',np.nan:'ปกติ'

  ,'ก้มหยิบของ':'ก้มเก็บของ' ,'ก้มหยิบเงิน':'ก้มเก็บของ','ก้มหยิบโทรศัพท์':'ก้มเก็บของ' ,'ก้มหยิบโทรศัพย์':'ก้มเก็บของ' ,'ก้มหาเงินค่าผ่านทาง':'ก้มเก็บของ' ,'ก้มเก็บของ':'ก้มเก็บของ' ,'ก้มเก็บของในรถ':'ก้มเก็บของ' ,'ก้มเก็บสิ่งของ':'ก้มเก็บของ' ,'ก้มเก็บสิ่งของในห้องโดยสาร':'ก้มเก็บของ' ,
   'ก้มเก็บเงิน':'ก้มเก็บของ' ,'ก้มเก็บโทรศัพท์':'ก้มเก็บของ' ,'ก้มเก็บโทรศัพย์':'ก้มเก็บของ' ,'ก้มดูโทรศัพย์':'ก้มเก็บของ' ,
   'ก้มรับโทรศัพท์':'ก้มเก็บของ' ,'ทำโทรศัพย์หล่นแล้วก้มหยิบ':'ก้มเก็บของ' ,'นั่งบุลคลอีซูซุก้มเก็บของ':'ก้มเก็บของ' ,'ประมาท ก้มหยิบของ':'ก้มเก็บของ' ,'ผู้ขับขี่ก้มหยิบของ':'ก้มเก็บของ' ,'หยิบของในรถ':'ก้มเก็บของ',

   'กำลังจะไปช่วย ว.40 ขึ้นบรมฯ':'การทำงานของราชการ','ตร.เรียกรถจอดออกหนังสือคำสั่ง':'การทำงานของราชการ','ลากกันมา':'การทำงานของราชการ'
   ,
   'กระบะToyotaทำสิ่งของตกหล่น':'ของตกจากรถ','มีกรงสุนัขตกหล่น':'ของตกจากรถ','มีเก้าอี้ตกหล่น':'ของตกจากรถ','ลงมาเก็บสิ่งของตกหล่นเลนขวา':'ของตกจากรถ'
   ,
   'ขับขี่ย้อนศร':'ขับขี่ย้อนศร','ขับขี่ย้อนเส้นทาง':'ขับขี่ย้อนศร','ขับย้อนทิศทางเดินรถ':'ขับขี่ย้อนศร','ขับขี่ย้อนศร':'ขับย้อนศร','ขับย้อนศรแล้วชน':'ขับย้อนศร','ขับย้อนเส้นทาง':'ขับย้อนศร','ขับรถย้อนทาง':'ขับย้อนศร','ขับรถย้อนทางมาจากทางลงสุขุมวิท':'ขับย้อนศร','ขับสวนเลน':'ขับย้อนศร','จยย.ย้อนศร':'ขับย้อนศร','มึนเมาแล้วขี่ย้อนศรทางเข้าด่าน':'ขับย้อนศร','ย้อนทางเข้าด่าน':'ขับย้อนศร'
   ,'ย้อนทางลงขึ้นมา':'ขับขี่ย้อนศร','ย้อนออกด่าน':'ขับขี่ย้อนศร','รถนั่งฮอนด้าขับย้อนทางลงพัฒ2':'ขับขี่ย้อนศร','วิ่งย้อนทางลงสุขุมวิท50ขึ้นมา':'ขับย้อนศร',

   'กลับรถไม่พ้น':'ขับชิดขอบทาง' , 'ขับชิดขวามากเกินไป': 'ขับชิดขอบทาง' , 'ขับชิดขวามากเกินไป':'ขับชิดขอบทาง', 'ขับชิดขอบเกินไป': 'ขับชิดขอบทาง','ขับชิดขอบตู้มากเกิน': 'ขับชิดขอบทาง','ขับชิดขอบทางขวามากเกินไป': 'ขับชิดขอบทาง',
   'ขับชิดขอบทางซ้าย': 'ขับชิดขอบทาง','ขับชิดขอบทางมาก': 'ขับชิดขอบทาง','ขับชิดซ้ายมากเกินไป': 'ขับชิดขอบทาง','ขับชิดมากเกินไป': 'ขับชิดขอบทาง' ,'ขับรถมุดเลนซ้าย':'ขับชิดขอบทาง',

   'ขับรถในระยะกระชันชิด':'ขับรถกระชั้นชิด' ,' ขับรถในระยะกระชั้นชิด':'ขับรถกระชั้นชิด' ,'  ขับรถระยะกระชั้นชิด':'ขับรถกระชั้นชิด' , 'เดินรถบนไหล่ทางซ้าย':'ขับรถกระชั้นชิด' , 'เดินรถไหล่ทางซ้าย':'ขับรถกระชั้นชิด'  ,'โดนรถบรรทุกเบียด':'ขับรถกระชั้นชิด' ,  'ถูกรถร่วมทางเบียด':'ขับรถกระชั้นชิด' ,  'เบรกกระชั้นชิด':'ขับรถกระชั้นชิด' ,  'เปลี่ยนช่องทางกะทันหัน':'ขับรถกระชั้นชิด' , 'รถบรรทุกตัดหน้า':'ขับรถกระชั้นชิด',

   'กระบะจอดช่วงทางโค้ง':'ขับรถประมาท' , 'กระบะจอดตรวจสอบสิ่งของ':'ขับรถประมาท' , 'ขับปาดกันไปมา':'ขับรถประมาท' , 'ขับรถคล่อมเลน':'ขับรถประมาท' , 'ขับรถชนป้าย':'ขับรถประมาท' , 'ช่องทางEasypass':'ขับรถประมาท', 'ขับรถด้วยความประมาท':'ขับรถประมาท' , 'ขับรถโดยประมาท':'ขับรถประมาท' , 'ขับรถประมาท':'ขับรถประมาท' , 'ขับรถปาดกันไป มา':'ขับรถประมาท' ,' ขับรถมองข้างทาง':'ขับรถประมาท' , 'ขับรถไม่ชำนาญ':'ขับรถประมาท' , 'ขับรถเร็วในช่องทางฉุกเฉิน':'ขับรถประมาท', 'ขับรถออกมองไม่เห็น':'ขับรถประมาท' , 'ขับเร็วเสียหลัก':'ขับรถประมาท' , 'ควบคุมรถไม่ได้':'ขับรถประมาท' , 'ชะลอดูว.40ฝั่งตรงข้าม':'ขับรถประมาท' , 'ใช้ความเร็วเข้าโค้ง':'ขับรถประมาท' ,
   'ใช้ความเร็วในการเข้าโค้ง':'ขับรถประมาท' , 'ใช้โทรศัพท์ขณะขับรถ':'ขับรถประมาท' , 'นับเงินทอนค่าผ่านทาง':'ขับรถประมาท' , 'ประมาณ':'ขับรถประมาท' , 'ประมาท':'ขับรถประมาท' , 'ประมาท':'ขับรถประมาท' , 'ขับรถเร็ว':'ขับรถประมาท' ,' ประมาทขาดความระวัง':'ขับรถประมาท' , 'เปิดประตูชำระค่าผ่านทาง':'ขับรถประมาท' , 'เปิดประตูมารับบัตรแล้วกระแทกตู':'ขับรถประมาท' , 'เปิดประตูรถ':'ขับรถประมาท',  'ผู้ขับขี่ขับรถประมาณ':'ขับรถประมาท' , 'ผู้ขับขี่นั่งบุคคลก้มดูโทรศัพท':'ขับรถประมาท' , 'มีสิ่งของขัดเบรกทำให้เกิดว40':'ขับรถประมาท' , 'ไม่ชะลอความเร็ว':'ขับรถประมาท' , 'ไม่ชินเส้นทาง':'ขับรถประมาท' , 'ไม่ดึงเบรกมือ':'ขับรถประมาท' , 'ไม่ดึงเบรกมือทำให้รถไหลตกท่อ':'ขับรถประมาท' , 'ไม่ได้ปิดประตูตู้บรรทุก':'ขับรถประมาท' ,'ไม่ได้ล็อคตู้':'ขับรถประมาท' , 'ไม่ทันมอง':'ขับรถประมาท' , 'ไม่ทันสังเกต':'ขับรถประมาท' , 'ไม่ระมัดระวัง':'ขับรถประมาท' , 'รถจอดเลนกลางโดนชนท้าย':'ขับรถประมาท' , 'รถบรรทุก6ล้อ':'ขับรถประมาท' , 'เข้าผิดเวลา':'ขับรถประมาท' , 'รองเท้าเบ้าไปขัดขาเบรค':'ขับรถประมาท' , 'ละสายตา':'ขับรถประมาท' , 'ละสายตาจากการขับขี่':'ขับรถประมาท' , 'เล่นโทรศัพท์':'ขับรถประมาท' , 'หยุดรถไม่ทัน':'ขับรถประมาท' , 'เหม่อลอย':'ขับรถประมาท',

   'ขับรถเร็ว':'ขับรถเร็วเกินไป', 'ข้ับรถเร็ว':'ขับรถเร็วเกินไป',  'ขับรถเร็ว':'ขับรถเร็วเกินไป', 'ประมาท':'ขับรถเร็วเกินไป', 'ขับรถเร็วเกินไป':'ขับรถเร็วเกินไป', 'ขับเร็วเฉี่ยวชนท้าย':'ขับรถเร็วเกินไป',

   'ขับรถช้าลง':'ขับรถช้าเกินไป',

   'กระบะบรรทุกสูง':'บรรทุกเกิน','ชนป้ายวัดความสูง':'บรรทุกเกิน','บรรทุกกว้างยื่นล้ำ':'บรรทุกเกิน','บรรทุกเกิน/ของตกหล่น':'บรรทุกเกิน','บรรทุกเกินตัวรถ':'บรรทุกเกิน','บรรทุกมาสูง':'บรรทุกเกิน','บรรทุกยื่นล้ำ':'บรรทุกเกิน',
   'บรรทุกยื่นล้ำตัวรถ':'บรรทุกเกิน','บรรทุกสิ่งของกว้างเกินไป':'บรรทุกเกิน','บรรทุกสิ่งของยื้นล้ำ':'บรรทุกเกิน','บรรทุกสูง':'บรรทุกเกิน','บรรทุกสูงเกิน':'บรรทุกเกิน','บรรทุกสูงหนัก':'บรรทุกเกิน','บรรทุกสูงหนักเกินไป':'บรรทุกเกิน',
   'เบรคไม่อยู่รถบรรทุกหนัก':'บรรทุกเกิน','รถบรรทุกหนัก':'บรรทุกเกิน',

   'กระบะเบรคกะทันหัน':'เบรครถกระทันหัน','นั่งบุคคลMazdaเบรกกะทันหัน':'เบรครถกระทันหัน','เบครกระทันหัน':'เบรครถกระทันหัน','เบรกกระชั้นชิด':'เบรครถกระทันหัน','เบรกกระทันหัน':'เบรครถกระทันหัน','เบรกกะทันหัน':'เบรครถกระทันหัน',
   'เบรกกะทันหันรถเสียการทรงตัว':'เบรครถกระทันหัน','เบรกไม่อยู่':'เบรครถกระทันหัน','เบรกแล้วเสียหลักพลิกคว่ำ':'เบรครถกระทันหัน','เบรคกระทันหหัน':'เบรครถกระทันหัน','เบรคกระทันหัน':'เบรครถกระทันหัน','เบรคกระทันหันเ':'เบรครถกระทันหัน',
   'เบรคกะทันหัน':'เบรครถกระทันหัน','เบรคไม่ทัน':'เบรครถกระทันหัน','เบรคไม่อยู่':'เบรครถกระทันหัน','เบรครถกระทันหัน':'เบรครถกระทันหัน','เบรครถกระทันหันแล้วพลิ๊กคว่ำ':'เบรครถกระทันหัน','เบรคแล้วเสียหลัก':'เบรครถกระทันหัน',
   'เบลคกระทันหัน':'เบรครถกระทันหัน','เปลี่ยนช่องทางเบรกกะทันหัน':'เบรครถกระทันหัน','ผู้ขับขี่เบรคกระทันหัน':'เบรครถกระทันหัน','ผู้ขับขี่เบรคไม่ทัน':'เบรครถกระทันหัน','เลรคกะทันหัน':'เบรครถกระทันหัน','เหยียบเบรคกระทันหัน':'เบรครถกระทันหัน',
   'เปลี่ยนช่องทางกระทันหัน':'เปลี่ยนช่องทางกระทันหัน',

   'ฝ่าฝืนสัญญาณ/ป้ายจราจร':'ฝ่าฝืนกฎจราจร',

   'คล้ายมีอาการมึนเมา':'มึนเมา','มึนเมา':'มึนเมา','เมาจอดนอนกีดขวาง':'มึนเมา',

   'เสียหลัก':'เสียหลัก', 'เสียหลักจากช่ิองทางด้านขวา':'เสียหลัก', 'เสียหลักพลิกคว่ำ':'เสียหลัก', 'เสียหลักหมุนชนขอบทาง':'เสียหลัก',

   'ป่วย':'โรคประจำตัว', 'ผู้ขับขี่หมดสติ':'โรคประจำตัว', 'โรคประจำตัว':'โรคประจำตัว',

   'กระจกแตก':'สาเหตุจากสภาพรถ/ถนน', 'กระบะจอดเสียเลนกลาง':'สาเหตุจากสภาพรถ/ถนน', 'แก๊สกระป๋องเล็กรั่ว':'สาเหตุจากสภาพรถ/ถนน', 'ขึ้นเนินมองไม่เห็น':'สาเหตุจากสภาพรถ/ถนน', 'ความร้อนขึ้นแล้วฟืนขับต่อ':'สาเหตุจากสภาพรถ/ถนน',
   'เครนฟาดเสาไฟเสียหาย':'สาเหตุจากสภาพรถ/ถนน', 'เครื่องยนต์ขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ช่วงล่างชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'ตัวรถสูง':'สาเหตุจากสภาพรถ/ถนน', 'ถนนเปียกลื่น':'สาเหตุจากสภาพรถ/ถนน',
   'น๊อตล้อหลังขวาขาด':'สาเหตุจากสภาพรถ/ถนน', 'บรรทุกรถ Atvเกิดไฟฟ้าลัดวงจร':'สาเหตุจากสภาพรถ/ถนน', 'เบรกชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'เบรกติด':'สาเหตุจากสภาพรถ/ถนน', 'เบรกติดล้อ':'สาเหตุจากสภาพรถ/ถนน',
   'เบรคขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'เบรคติด':'สาเหตุจากสภาพรถ/ถนน', 'เบรคแตก':'สาเหตุจากสภาพรถ/ถนน', 'ปีกนกซ้ายชำรุด':'สาเหตุจากสภาพรถ/ถนน', 'ฝนตกถนนเปียกลื่น':'สาเหตุจากสภาพรถ/ถนน',
   'ฝนตกถนนลื่น':'สาเหตุจากสภาพรถ/ถนน', 'ฝาท้ายตู้เปิด':'สาเหตุจากสภาพรถ/ถนน', 'พวงมาลัยล็อค':'สาเหตุจากสภาพรถ/ถนน', 'พวงมาลัยล๊อค':'สาเหตุจากสภาพรถ/ถนน', 'พ่วงหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'เพลาข้างด้านขวาขาด':'สาเหตุจากสภาพรถ/ถนน', 'เพลิงไหม้':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้ารัดวงจรในห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้าลัดวงจร':'สาเหตุจากสภาพรถ/ถนน', 'ไฟฟ้าลัดวงจรบริเวณห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน',
   'มองไม่เห็น':'สาเหตุจากสภาพรถ/ถนน', 'มีกลุ่มควันขึ้นมากหลังรถ':'สาเหตุจากสภาพรถ/ถนน', 'มีควันขึ้นที่ห้องเครื่อง':'สาเหตุจากสภาพรถ/ถนน', 'มีรถจอดเสียช่องกลาง ชนท้าย':'สาเหตุจากสภาพรถ/ถนน', 'ยากแตก':'สาเหตุจากสภาพรถ/ถนน',
   'ยางแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกล้อหลัง':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกเสียหลัก':'สาเหตุจากสภาพรถ/ถนน', 'ยางแตกเสียหลักชนขอบทาง':'สาเหตุจากสภาพรถ/ถนน', 'ยางระเบิด':'สาเหตุจากสภาพรถ/ถนน',
   'ยางล้อหลังขวาระเบิด':'สาเหตุจากสภาพรถ/ถนน', 'ยางหน้าขวาแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลงขวาระเบิด':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลังขวาแตก':'สาเหตุจากสภาพรถ/ถนน', 'ยางหลังซ้ายแตก':'สาเหตุจากสภาพรถ/ถนน',
   'ยางหลังแตก2ข้าง':'สาเหตุจากสภาพรถ/ถนน', 'ยางเเตก':'สาเหตุจากสภาพรถ/ถนน', 'รถเบรกไม่อยู่':'สาเหตุจากสภาพรถ/ถนน', 'รถมีขนาดใหญ่เกินไป':'สาเหตุจากสภาพรถ/ถนน', 'รถยนต์ขัดข้อง':'สาเหตุจากสภาพรถ/ถนน',
   'รถไหล':'สาเหตุจากสภาพรถ/ถนน', 'ระบบไฟฟ้าขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ระบบไฮโดรลิคขัดข้อง':'สาเหตุจากสภาพรถ/ถนน', 'ล้อล็อค':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลังขวาหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'ล้อหลุด':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลุดไปชนรถคู่กรณี':'สาเหตุจากสภาพรถ/ถนน', 'ล้อหลุดเสียหลักพลิกคว่ำ':'สาเหตุจากสภาพรถ/ถนน', 'สภาพแวดล้อม':'สาเหตุจากสภาพรถ/ถนน', 'สลักตัวยึดหลุด':'สาเหตุจากสภาพรถ/ถนน',
   'สาเหตุจากสภาพรถ/ถนน':'สาเหตุจากสภาพรถ/ถนน', 'หางพ่วงเรือเจ๊ตสกรีหลุด':'สาเหตุจากสภาพรถ/ถนน', 'เหยียบสิ้งของตกหล่นแผ่นเหล็ก':'สาเหตุจากสภาพรถ/ถนน', 'อุปกรณ์ล้อยางชำรุด':'สาเหตุจากสภาพรถ/ถนน',

   'หลบจักรยานยนต์':'หลบรถ', 'หลบมีรถย้อนทาง':'หลบรถ',

   'สันนิษฐาน หลับใน':'หลับใน', 'หลับใน':'หลับใน',

   'ขับถอยหลัง':'ถอยรถ','ขับรถถอยหลัง':'ถอยรถ','ถอยเบียดแท่นปูน':'ถอยรถ','ถอยหลบมองไม่เห็นชนป้ายจราจร':'ถอยรถ','ถอยหลังเข้าตู้ผิด':'ถอยรถ','ถอยหลังจอด':'ถอยรถ','ถอยหลังชน':'ถอยรถ','ถอยหลังชนไม้กั้น':'ถอยรถ','ถอยหลังชิดขอบทางขวามากเกินไป':'ถอยรถ','ถอยหลังชิดด้านซ้ายมากเกินไป':'ถอยรถ','ถอยหลังรถไปชน':'ถอยรถ','ถอยหลังลงจากต่างระดับ':'ถอยรถ','นั่งสาธารณะขับเลยทางลงถอยหลัง':'ถอยรถ',

   'ชนแล้วหลบหนี':'ชนแล้วหลบหนี',

   'คันที่3หยุดรถไม่ทัน':'ชนท้าย','ชนท้าย':'ชนท้าย','ชนท้ายตามลำดับ':'ชนท้าย','ชนท้ายรถบรรทุก':'ชนท้าย','โดนชนท้าย':'ชนท้าย','นั่งบุคคลIsuzuเบรคไม่ทัน':'ชนท้าย',

   'เฉี่ยวชนก้างปลา':'เฉี่ยวชน','เฉียวชนแล้วหลบหนี':'เฉี่ยวชน','เชี่ยวชน':'เฉี่ยวชน','โดนตัดหน้า':'เฉี่ยวชน','โดนปาดหน้า':'เฉี่ยวชน','นั่งบุคคลตัดหน้ารถบรรทุก10ล้อ':'เฉี่ยวชน','มีรถปาดหน้า':'เฉี่ยวชน',

   'ขับรถในช่องทางฉุกเฉิน':'เข้าผิดช่อง','เข้าช่องetc':'เข้าผิดช่อง','เข้าช่องเก็บค่าผ่านทางผิด':'เข้าผิดช่อง','เข้าช่องเก็บค่าผ่านผิด':'เข้าผิดช่อง','เข้าช่องเก็บเงินผิด':'เข้าผิดช่อง','เข้าช่องทางผิด':'เข้าผิดช่อง','เข้าช่องทางผิดเเล้วถอยรถออก':'เข้าผิดช่อง','เข้าผิดช่องทาง':'เข้าผิดช่อง','เข้าผิดช่ิอง':'เข้าผิดช่อง','เข้าผิดตู้':'เข้าผิดช่อง','เข้าผิดเลนถอยชนไฟส่องล้อเสียหา':'เข้าผิดช่อง','จอดในช่องเดินรถซ้าย':'เข้าผิดช่อง','จอดเลนฉุกเฉิน':'เข้าผิดช่อง','เดินรถในเลนฉุกเฉิน':'เข้าผิดช่อง','พลัดหลง':'เข้าผิดช่อง','ไม่มีeasy pass':'เข้าผิดช่อง','ไม่มีอีซี่พาส':'เข้าผิดช่อง','รถไม่่มี Easy Pass':'เข้าผิดช่อง','ลงผิดทางถอยหลัง':'เข้าผิดช่อง','วิ่งช่องฉุกเฉิน':'เข้าผิดช่อง','วิ่งเลนฉุกเฉิน':'เข้าผิดช่อง','หลงทาง':'เข้าผิดช่อง','หลงทางแล้วถอยชน':'เข้าผิดช่อง'
  }
newgroup.replace(k)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0               โรคประจำตัว
# 1                       NaN
# 2                ก้มเก็บของ
# 3                ก้มเก็บของ
# 4                บรรทุกหนัก
#                ...
# 6552    สาเหตุจากสภาพรถ/ถนน
# 6553            ขับรถประมาท
# 6554        ขับรถเร็วเกินไป
# 6555    สาเหตุจากสภาพรถ/ถนน
# 6556    สาเหตุจากสภาพรถ/ถนน
# Name: cause, Length: 6557, dtype: object

# %%
print(len(set(k)))
# Out:
# 288
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Create New Dataframe
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_newer = {'day':day, 'month' : mon, 'year' : year, 'time':time_lable, 'road':name_road, 'weather':weather_road,'injur':injur,'cause_A':data_association_rules,'cause_D':newk,'dead':dead}
data_new = pd.DataFrame(data_newer)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_new = data_new.dropna()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_new.to_excel('use_data.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_new
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      day month  year  time road weather injur              cause_A cause_D  \
# 0     15    03  2016     0    0       0     0          โรคประจำตัว       0
# 2     09    12  2015     1    0       0     0           ก้มเก็บของ       0
# 3     20    08  2016     1    0       0     0           ก้มเก็บของ       0
# 4     23    04  2016     0    0       0     0           บรรทุกเกิน       0
# 5     17    09  2016     0    0       0     3      เบรครถกระทันหัน       1
# ...   ..   ...   ...   ...  ...     ...   ...                  ...     ...
# 6552  04    10  2021     1    2       0     1  สาเหตุจากสภาพรถ/ถนน       2
# ...

# %%
x=data_new[['weather',	'injur',	'cause_A']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_new['Cfor_A'] = x[x.columns[:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_new
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      day month  year  time road weather injur              cause_A cause_D  \
# 0     15    03  2016     0    0       0     0          โรคประจำตัว       0
# 2     09    12  2015     1    0       0     0           ก้มเก็บของ       0
# 3     20    08  2016     1    0       0     0           ก้มเก็บของ       0
# 4     23    04  2016     0    0       0     0           บรรทุกเกิน       0
# 5     17    09  2016     0    0       0     3      เบรครถกระทันหัน       1
# ...   ..   ...   ...   ...  ...     ...   ...                  ...     ...
# 6552  04    10  2021     1    2       0     1  สาเหตุจากสภาพรถ/ถนน       2
# ...

# %%
data_new.groupby(['month']).sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-112-3d2da5921d2c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_new.groupby(['month']).sum()
#        time
# month
# 01      637
# 02      748
# 03      790
# 04      645
# 05      720
# 06      791
# 07      789
# 08      658
# 09      733
# 10      897
# 11      824
# 12      931

# %%
data_new.groupby('month')['Cfor_A'].apply(list)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# month
# 01    [0,0,ขับรถประมาท, 0,0,ขับรถเร็วเกินไป, 0,0,เฉี...
# 02    [0,1,โรคประจำตัว, 0,0,ก้มเก็บของ, 0,1,โรคประจำ...
# 03    [0,0,โรคประจำตัว, 0,0,มึนเมา, 0,0,หลับใน, 0,0,...
# 04    [0,0,บรรทุกเกิน, 0,0,ก้มเก็บของ, 0,1,ก้มเก็บขอ...
# 05    [0,0,หลับใน, 0,1,หลับใน, 0,0,หลับใน, 0,1,หลับใ...
# 06    [0,0,โรคประจำตัว, 0,0,ขับขี่ย้อนศร, 0,0,สาเหตุ...
# 07    [0,0,หลบรถ, 0,0,ขับขี่ย้อนศร, 0,0,ขับรถประมาท,...
# 08    [0,0,ก้มเก็บของ, 0,0,ถอยรถ, 0,3,ขับขี่ย้อนศร, ...
# 09    [0,3,เบรครถกระทันหัน, 0,0,ขับรถประมาท, 0,0,ขับ...
# 10    [0,0,ขับรถประมาท, 0,1,ขับรถประมาท, 0,2,มึนเมา,...
# ...

# %%
data_MC = data_new.groupby(['month'])['Cfor_A'].apply(list).reset_index()
trans_data_MC = data_MC['Cfor_A'].apply(lambda x: [str(item) for item in x])
trans_data_MC
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0     [0,0,ขับรถประมาท, 0,0,ขับรถเร็วเกินไป, 0,0,เฉี...
# 1     [0,1,โรคประจำตัว, 0,0,ก้มเก็บของ, 0,1,โรคประจำ...
# 2     [0,0,โรคประจำตัว, 0,0,มึนเมา, 0,0,หลับใน, 0,0,...
# 3     [0,0,บรรทุกเกิน, 0,0,ก้มเก็บของ, 0,1,ก้มเก็บขอ...
# 4     [0,0,หลับใน, 0,1,หลับใน, 0,0,หลับใน, 0,1,หลับใ...
# 5     [0,0,โรคประจำตัว, 0,0,ขับขี่ย้อนศร, 0,0,สาเหตุ...
# 6     [0,0,หลบรถ, 0,0,ขับขี่ย้อนศร, 0,0,ขับรถประมาท,...
# 7     [0,0,ก้มเก็บของ, 0,0,ถอยรถ, 0,3,ขับขี่ย้อนศร, ...
# 8     [0,3,เบรครถกระทันหัน, 0,0,ขับรถประมาท, 0,0,ขับ...
# 9     [0,0,ขับรถประมาท, 0,1,ขับรถประมาท, 0,2,มึนเมา,...
# 10    [0,0,บรรทุกเกิน, 0,1,มึนเมา, 0,1,หลับใน, 0,2,ข...
# ...

# %%
data_new[['weather',	'injur',	'cause_A']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      weather injur              cause_A
# 0          0     0          โรคประจำตัว
# 2          0     0           ก้มเก็บของ
# 3          0     0           ก้มเก็บของ
# 4          0     0           บรรทุกเกิน
# 5          0     3      เบรครถกระทันหัน
# ...      ...   ...                  ...
# 6552       0     1  สาเหตุจากสภาพรถ/ถนน
# 6553       0     1          ขับรถประมาท
# 6554       1     0      ขับรถเร็วเกินไป
# 6555       0     0  สาเหตุจากสภาพรถ/ถนน
# 6556       1     0  สาเหตุจากสภาพรถ/ถนน
#
# [6538 rows x 3 columns]

# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Convert the data to a one-hot encoded DataFrame
accident_encoded = pd.get_dummies(data_new[['weather', 'injur','cause_A']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Combine one-hot encoded columns with the original DataFrame
accident_df_encoded = pd.concat([data_new['road'], accident_encoded], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
accident_df_encoded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      road  weather_0  weather_1  weather_2  weather_3  injur_0  injur_1  \
# 0       0          1          0          0          0        1        0
# 2       0          1          0          0          0        1        0
# 3       0          1          0          0          0        1        0
# 4       0          1          0          0          0        1        0
# 5       0          1          0          0          0        0        0
# ...   ...        ...        ...        ...        ...      ...      ...
# 6552    2          1          0          0          0        0        1
# ...

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
accident_df_encoded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      road  weather_0  weather_1  weather_2  weather_3  injur_0  injur_1  \
# 0       0          1          0          0          0        1        0
# 2       0          1          0          0          0        1        0
# 3       0          1          0          0          0        1        0
# 4       0          1          0          0          0        1        0
# 5       0          1          0          0          0        0        0
# ...   ...        ...        ...        ...        ...      ...      ...
# 6552    2          1          0          0          0        0        1
# ...

# %%
accident_df_encoded.iloc[:, 1:]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       weather_0  weather_1  weather_2  weather_3  injur_0  injur_1  injur_2  \
# 0             1          0          0          0        1        0        0
# 2             1          0          0          0        1        0        0
# 3             1          0          0          0        1        0        0
# 4             1          0          0          0        1        0        0
# 5             1          0          0          0        0        0        0
# ...         ...        ...        ...        ...      ...      ...      ...
# 6552          1          0          0          0        0        1        0
# ...

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(accident_df_encoded.iloc[:, 1:], min_support=0.20, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Display frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)

print("\nAssociation Rules:")
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#     support                                       itemsets
# 0  0.947232                                    (weather_0)
# 1  0.680483                                      (injur_0)
# 2  0.436831                      (cause_A_ขับรถเร็วเกินไป)
# 3  0.214745              (cause_A_เปลี่ยนช่องทางกระทันหัน)
# ...

# %%
frequent_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                                       itemsets
# 0  0.947232                                    (weather_0)
# 1  0.680483                                      (injur_0)
# 2  0.436831                      (cause_A_ขับรถเร็วเกินไป)
# 3  0.214745              (cause_A_เปลี่ยนช่องทางกระทันหัน)
# 4  0.644387                           (weather_0, injur_0)
# 5  0.409147           (cause_A_ขับรถเร็วเกินไป, weather_0)
# 6  0.201744   (weather_0, cause_A_เปลี่ยนช่องทางกระทันหัน)
# 7  0.276384             (cause_A_ขับรถเร็วเกินไป, injur_0)
# 8  0.257724  (cause_A_ขับรถเร็วเกินไป, weather_0, injur_0)

# %% [markdown]
# ##ช่วงหลังเที่ยงคืน

# %%
data_new
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      day month  year  time road weather injur              cause_A cause_D  \
# 0     15    03  2016     0    0       0     0          โรคประจำตัว       0
# 2     09    12  2015     1    0       0     0           ก้มเก็บของ       0
# 3     20    08  2016     1    0       0     0           ก้มเก็บของ       0
# 4     23    04  2016     0    0       0     0           บรรทุกเกิน       0
# 5     17    09  2016     0    0       0     3      เบรครถกระทันหัน       1
# ...   ..   ...   ...   ...  ...     ...   ...                  ...     ...
# 6552  04    10  2021     1    2       0     1  สาเหตุจากสภาพรถ/ถนน       2
# ...

# %%
data_after_midnight=data_new[data_new["time"]==3]
data_after_midnight #data ที่เป็นเฉพาะของหลังเที่นงคืน
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      day month  year  time road weather injur                  cause_A  \
# 6     09    07  2016     3    1       0     0                    หลบรถ
# 7     30    07  2016     3    1       0     0             ขับขี่ย้อนศร
# 9     20    06  2016     3    1       0     0              โรคประจำตัว
# 16    07    04  2016     3    3       0     0               ก้มเก็บของ
# 18    20    01  2016     3    3       0     0          ขับรถเร็วเกินไป
# ...   ..   ...   ...   ...  ...     ...   ...                      ...
# 6509  21    10  2021     3    1       0     0               บรรทุกเกิน
# ...

# %%
data_after_midnight[['weather',	'injur',	'cause_A']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      weather injur                  cause_A
# 6          0     0                    หลบรถ
# 7          0     0             ขับขี่ย้อนศร
# 9          0     0              โรคประจำตัว
# 16         0     0               ก้มเก็บของ
# 18         0     0          ขับรถเร็วเกินไป
# ...      ...   ...                      ...
# 6509       0     0               บรรทุกเกิน
# 6520       1     2          ขับรถเร็วเกินไป
# 6527       0     0  เปลี่ยนช่องทางกระทันหัน
# 6532       0     2                   หลับใน
# 6535       0     1                   หลับใน
#
# [1355 rows x 3 columns]

# %%
# Convert the data to a one-hot encoded DataFrame
accident_encoded_midnight = pd.get_dummies(data_after_midnight[['weather', 'injur','cause_A']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Combine one-hot encoded columns with the original DataFrame
accident_df_encoded_midnight = pd.concat([data_after_midnight['road'], accident_encoded_midnight], axis=1)
accident_df_encoded_midnight
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      road  weather_0  weather_1  weather_2  weather_3  injur_0  injur_1  \
# 6       1          1          0          0          0        1        0
# 7       1          1          0          0          0        1        0
# 9       1          1          0          0          0        1        0
# 16      3          1          0          0          0        1        0
# 18      3          1          0          0          0        1        0
# ...   ...        ...        ...        ...        ...      ...      ...
# 6509    1          1          0          0          0        1        0
# ...

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets_midnight = apriori(accident_df_encoded_midnight.iloc[:, 1:], min_support=0.3, use_colnames=True)

# Generate association rules
rules_midnight = association_rules(frequent_itemsets_midnight, metric="confidence", min_threshold=0.2)

# Display frequent itemsets and association rules
print("Frequent Itemsets_midnight:")
print(frequent_itemsets)

print("\nAssociation Rules_midnight:")
rules_midnight
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets_midnight:
#     support                                       itemsets
# 0  0.947232                                    (weather_0)
# 1  0.680483                                      (injur_0)
# 2  0.436831                      (cause_A_ขับรถเร็วเกินไป)
# 3  0.214745              (cause_A_เปลี่ยนช่องทางกระทันหัน)
# ...
