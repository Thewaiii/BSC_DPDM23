# %% [markdown]
# <a href="https://colab.research.google.com/github/Thewaiii/BSC_DPDM23/blob/main/ProJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Association rules

# %%
from google.colab import drive
drive.mount('/content/drive')
path ='/content/drive/MyDrive/BSC_DBDM23/use_data-2.xlsx'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("/content/drive/MyDrive/BSC_DBDM23/use_data-2.xlsx")

# %%
data.isnull().any()
# Out:
# Unnamed: 0    False
# day           False
# month         False
# year          False
# time          False
# road          False
# weather       False
# injur         False
# cause_A       False
# cause_D       False
# dead          False
# dtype: bool

# %%
len(data)
# Out:
# 6538

# %%
data
# Out:
#       Unnamed: 0  day  month  year  time  road  weather  injur  \
# 0              0   15      3  2016     0     0        0      0
# 1              2    9     12  2015     1     0        0      0
# 2              3   20      8  2016     1     0        0      0
# 3              4   23      4  2016     0     0        0      0
# 4              5   17      9  2016     0     0        0      3
# ...          ...  ...    ...   ...   ...   ...      ...    ...
# 6533        6552    4     10  2021     1     2        0      1
# 6534        6553    3     10  2021     0     5        0      1
# 6535        6554    3     10  2021     2     7        1      0
# 6536        6555    1     10  2021     0     0        0      0
# 6537        6556    1     10  2021     1     7        1      0
#
#                   cause_A  cause_D  dead
# 0             โรคประจำตัว        0     0
# 1              ก้มเก็บของ        0     0
# 2              ก้มเก็บของ        0     0
# 3              บรรทุกเกิน        0     0
# ...

# %%
data.groupby(['month']).sum()
# Out:
# <ipython-input-43-13d1bbbbd741>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['month']).sum()
#        Unnamed: 0    day     year  time  road  weather  injur  cause_D  dead
# month
# 1         1448698   8103   932575   598  1296        8    264      165     6
# 2         1698163   7799  1098108   695  1478        5    315      200     4
# 3         2142494   9353  1187258   735  1733       11    328      192     3
# 4         1623877   7270   940868   602  1256       12    235      147     4
# 5         1845852   8681  1064061   671  1472       45    260      181     3
# 6         1799256   9227  1128506   751  1587       48    300      191     5
# 7         1807378   8779  1112385   744  1542       50    271      199     8
# ...

# %%
data.groupby('month')['cause_A'].apply(list)
# Out:
# month
# 1     [ขับรถประมาท, ขับรถเร็วเกินไป, เฉี่ยวชน, มึนเม...
# 2     [โรคประจำตัว, ก้มเก็บของ, โรคประจำตัว, ขับขี่ย...
# 3     [โรคประจำตัว, มึนเมา, หลับใน, หลับใน, ขับรถเร็...
# 4     [บรรทุกเกิน, ก้มเก็บของ, ก้มเก็บของ, มึนเมา, ห...
# 5     [หลับใน, หลับใน, หลับใน, หลับใน, หลับใน, ขับรถ...
# 6     [โรคประจำตัว, ขับขี่ย้อนศร, สาเหตุจากสภาพรถ/ถน...
# 7     [หลบรถ, ขับขี่ย้อนศร, ขับรถประมาท, หลับใน, หลั...
# 8     [ก้มเก็บของ, ถอยรถ, ขับขี่ย้อนศร, ถอยรถ, ก้มเก...
# 9     [เบรครถกระทันหัน, ขับรถประมาท, ขับรถประมาท, ขั...
# 10    [ขับรถประมาท, ขับรถประมาท, มึนเมา, มึนเมา, หลั...
# 11    [บรรทุกเกิน, มึนเมา, หลับใน, ขับรถช้าเกินไป, ข...
# 12    [ก้มเก็บของ, ขับรถประมาท, หลับใน, หลับใน, หลับ...
# Name: cause_A, dtype: object

# %%
# !pip install apyori
from apyori import apriori

# %%
data_MC = data.groupby(['road','month'])['cause_A'].apply(list).reset_index()
trans_data_MC = data_MC['cause_A'].apply(lambda x: [str(item) for item in x])
trans_data_MC
# Out:
# 0      [ขับรถเร็วเกินไป, ขับรถเร็วเกินไป, ขับรถเร็วเก...
# 1      [ขับรถเร็วเกินไป, ขับรถเร็วเกินไป, ขับรถเร็วเก...
# 2      [โรคประจำตัว, ขับรถเร็วเกินไป, ขับรถเร็วเกินไป...
# 3      [บรรทุกเกิน, หลับใน, ขับรถเร็วเกินไป, ขับรถเร็...
# 4      [หลับใน, หลับใน, ขับรถเร็วเกินไป, ขับรถเร็วเกิ...
#                              ...
# 102                                [สาเหตุจากสภาพรถ/ถนน]
# 103    [เปลี่ยนช่องทางกระทันหัน, ขับรถเร็วเกินไป, ขับ...
# 104    [หลับใน, สาเหตุจากสภาพรถ/ถนน, สาเหตุจากสภาพรถ/...
# 105    [ขับรถเร็วเกินไป, สาเหตุจากสภาพรถ/ถนน, ขับรถเร...
# 106    [ขับรถเร็วเกินไป, สาเหตุจากสภาพรถ/ถนน, สาเหตุจ...
# Name: cause_A, Length: 107, dtype: object

# %%
min_sup = 0.31

sup_data_MC = list(apriori(trans_data_MC, min_support = min_sup))
for i in sup_data_MC:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'ขับรถกระชั้นชิด', 'ขับรถประมาท'}), support=0.38317757009345793, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ขับรถกระชั้นชิด', 'ขับรถประมาท'}), confidence=0.38317757009345793, lift=1.0), OrderedStatistic(items_base=frozenset({'ขับรถกระชั้นชิด'}), items_add=frozenset({'ขับรถประมาท'}), confidence=0.7884615384615384, lift=1.429921773142112), OrderedStatistic(items_base=frozenset({'ขับรถประมาท'}), items_add=frozenset({'ขับรถกระชั้นชิด'}), confidence=0.6949152542372882, lift=1.429921773142112)])
# yes
# ...
